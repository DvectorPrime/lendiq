# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import xgboost as xgb

# %%
df = pd.read_csv("data/train.csv")

# %%
df.describe()
# Out:
#                   ID   CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT  \
# count  215257.000000  215257.000000      2.152570e+05  2.152570e+05
# mean   277916.285552       0.416567      1.683448e+05  5.996394e+05
# std    102805.880546       0.721898      1.023409e+05  4.030145e+05
# min    100002.000000       0.000000      2.565000e+04  4.500000e+04
# 25%    188825.000000       0.000000      1.125000e+05  2.700000e+05
# 50%    277695.000000       0.000000      1.462500e+05  5.155290e+05
# 75%    366772.000000       1.000000      2.025000e+05  8.086500e+05
# max    456255.000000      19.000000      9.000000e+06  4.050000e+06
#
#          AMT_ANNUITY  AMT_GOODS_PRICE       DAYS_AGE  DAYS_EMPLOYMENT  \
# count  215249.000000     2.150540e+05  215257.000000    215257.000000
# mean    27128.366938     5.388528e+05  -16040.968814     64138.989292
# std     14521.116795     3.699160e+05    4367.736464    141546.368713
# min      1615.500000     4.050000e+04  -25201.000000    -17912.000000
# 25%     16551.000000     2.385000e+05  -19697.000000     -2758.000000
# 50%     24930.000000     4.500000e+05  -15756.000000     -1209.000000
# 75%     34605.000000     6.795000e+05  -12409.000000      -288.000000
# max    230161.500000     4.050000e+06   -7676.000000    365243.000000
#
#        DAYS_ID_PUBLISH   OWN_CAR_AGE  ...  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# count    215257.000000  73305.000000  ...     215257.000000     215257.000000
# mean      -2995.073206     12.053175  ...          0.000506          0.000330
# std        1509.053098     11.920288  ...          0.022497          0.018158
# min       -6383.000000      0.000000  ...          0.000000          0.000000
# 25%       -4298.000000      5.000000  ...          0.000000          0.000000
# 50%       -3257.000000      9.000000  ...          0.000000          0.000000
# 75%       -1722.000000     15.000000  ...          0.000000          0.000000
# max           0.000000     91.000000  ...          1.000000          1.000000
#
#        AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# count               186162.000000              186162.000000
# mean                     0.006494                   0.006935
# std                      0.084051                   0.108859
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      3.000000                   9.000000
#
#        AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# count               186162.000000              186162.000000
# mean                     0.034486                   0.268175
# std                      0.203859                   0.922865
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      8.000000                  27.000000
#
#        AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  EXT_SOURCE_4  \
# count              186162.000000                186162.00000  2.147930e+05
# mean                    0.265264                     1.90107  2.571639e-01
# std                     0.860637                     1.86733  1.850209e-01
# min                     0.000000                     0.00000  2.436734e-08
# 25%                     0.000000                     0.00000  9.779965e-02
# 50%                     0.000000                     1.00000  2.257796e-01
# 75%                     0.000000                     3.00000  3.940680e-01
# max                   261.000000                    25.00000  8.059096e-01
#
#               TARGET
# count  215257.000000
# mean        0.081057
# std         0.272923
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 88 columns]

# %%
columns_to_keep = [
    'DAYS_AGE',
    'NAME_INCOME_TYPE',
    'DAYS_EMPLOYMENT',
    'NAME_EDUCATION_TYPE',
    'NAME_FAMILY_STATUS',
    'AMT_ANNUITY',
    'CNT_CHILDREN',
    'CNT_FAM_MEMBERS',
    'AMT_INCOME_TOTAL',
    'FLAG_OWN_CAR',
    'FLAG_OWN_REALTY',
    'NAME_HOUSING_TYPE',
    'AMT_CREDIT',
    'TARGET'
]

df_final = df[columns_to_keep]

print("Final DataFrame Shape:", df_final.shape)
print("\nFirst 3 rows:")
print(df_final.head(3))
# Out:
# Final DataFrame Shape: (215257, 14)
#
# First 3 rows:
#    DAYS_AGE      NAME_INCOME_TYPE  DAYS_EMPLOYMENT  \
# 0    -22008             Pensioner           365243
# 1     -8506  Commercial associate             -313
# 2    -11579               Working            -2651
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  AMT_ANNUITY  \
# 0  Secondary / secondary special                 Widow      37800.0
# 1  Secondary / secondary special  Single / not married      40963.5
# 2  Secondary / secondary special               Married      19795.5
#
#    CNT_CHILDREN  CNT_FAM_MEMBERS  AMT_INCOME_TOTAL FLAG_OWN_CAR  \
# 0             0              1.0          427500.0            N
# 1             0              1.0          180000.0            Y
# 2             1              3.0          112500.0            Y
#
#   FLAG_OWN_REALTY  NAME_HOUSING_TYPE  AMT_CREDIT  TARGET
# 0               Y  House / apartment   1288350.0       0
# 1               Y  House / apartment    848745.0       0
# 2               Y   Rented apartment    385164.0       0

# %%
df_final.describe()
# Out:
#             DAYS_AGE  DAYS_EMPLOYMENT    AMT_ANNUITY   CNT_CHILDREN  \
# count  215257.000000    215257.000000  215249.000000  215257.000000
# mean   -16040.968814     64138.989292   27128.366938       0.416567
# std      4367.736464    141546.368713   14521.116795       0.721898
# min    -25201.000000    -17912.000000    1615.500000       0.000000
# 25%    -19697.000000     -2758.000000   16551.000000       0.000000
# 50%    -15756.000000     -1209.000000   24930.000000       0.000000
# 75%    -12409.000000      -288.000000   34605.000000       1.000000
# max     -7676.000000    365243.000000  230161.500000      19.000000
#
#        CNT_FAM_MEMBERS  AMT_INCOME_TOTAL    AMT_CREDIT         TARGET
# count    215255.000000      2.152570e+05  2.152570e+05  215257.000000
# mean          2.150882      1.683448e+05  5.996394e+05       0.081057
# std           0.910791      1.023409e+05  4.030145e+05       0.272923
# min           1.000000      2.565000e+04  4.500000e+04       0.000000
# 25%           2.000000      1.125000e+05  2.700000e+05       0.000000
# 50%           2.000000      1.462500e+05  5.155290e+05       0.000000
# 75%           3.000000      2.025000e+05  8.086500e+05       0.000000
# max          20.000000      9.000000e+06  4.050000e+06       1.000000

# %%
missing_counts = df_final.isnull().sum()
missing_counts = missing_counts[missing_counts > 0]

cols_with_missing = df_final[missing_counts.index].columns
df_final[cols_with_missing] = df_final[cols_with_missing].fillna(df_final[cols_with_missing].median())
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6732\543198922.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[cols_with_missing] = df_final[cols_with_missing].fillna(df_final[cols_with_missing].median())

# %%
df_final['AGE_YEARS'] = abs(df_final['DAYS_AGE']) // 365
df_final['YEARS_EMPLOYED'] = abs(df_final['DAYS_EMPLOYMENT']) // 365

df_final = df_final.drop(columns=['DAYS_AGE', 'DAYS_EMPLOYMENT'])
df_final
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6732\1070940031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['AGE_YEARS'] = abs(df_final['DAYS_AGE']) // 365
# C:\Users\user\AppData\Local\Temp\ipykernel_6732\1070940031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['YEARS_EMPLOYED'] = abs(df_final['DAYS_EMPLOYMENT']) // 365
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  Pensioner  Secondary / secondary special
# 1       Commercial associate  Secondary / secondary special
# 2                    Working  Secondary / secondary special
# 3                  Pensioner  Secondary / secondary special
# 4                    Working  Secondary / secondary special
# ...                      ...                            ...
# 215252               Working  Secondary / secondary special
# 215253               Working  Secondary / secondary special
# 215254  Commercial associate              Incomplete higher
# 215255               Working  Secondary / secondary special
# 215256               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  AMT_ANNUITY  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0                      Widow      37800.0             0              1.0
# 1       Single / not married      40963.5             0              1.0
# 2                    Married      19795.5             1              3.0
# 3                    Married      60867.0             0              2.0
# 4                    Married      26316.0             0              2.0
# ...                      ...          ...           ...              ...
# 215252               Married      70956.0             0              2.0
# 215253               Married      14751.0             1              3.0
# 215254        Civil marriage      30258.0             0              2.0
# 215255             Separated      19206.0             0              1.0
# 215256               Married      28030.5             0              2.0
#
#         AMT_INCOME_TOTAL FLAG_OWN_CAR FLAG_OWN_REALTY  NAME_HOUSING_TYPE  \
# 0               427500.0            N               Y  House / apartment
# 1               180000.0            Y               Y  House / apartment
# 2               112500.0            Y               Y   Rented apartment
# 3               540000.0            N               Y  House / apartment
# 4                76500.0            Y               Y  House / apartment
# ...                  ...          ...             ...                ...
# 215252          144000.0            Y               N  House / apartment
# 215253          148500.0            N               N       With parents
# 215254          270000.0            Y               Y  House / apartment
# 215255          225000.0            N               Y  House / apartment
# 215256          189000.0            N               Y  House / apartment
#
#         AMT_CREDIT  TARGET  AGE_YEARS  YEARS_EMPLOYED
# 0        1288350.0       0         60            1000
# 1         848745.0       0         23               0
# 2         385164.0       0         31               7
# 3        1433520.0       0         58            1000
# 4         900000.0       0         58              37
# ...            ...     ...        ...             ...
# 215252    701730.0       0         50               4
# 215253    254700.0       0         29               6
# 215254   1030500.0       0         42               5
# 215255    433057.5       1         53               4
# 215256    954207.0       0         52               4
#
# [215257 rows x 14 columns]

# %%
abnormal_age_count = (df_final['AGE_YEARS'] > 70).sum()
print(f"Number of people over 70 years old: {abnormal_age_count}")

# 2. Count unrealistic employment lengths (e.g., working > 50 years)
abnormal_emp_count = (df_final['YEARS_EMPLOYED'] > 50).sum()
print(f"Number of people working > 50 years: {abnormal_emp_count}")

anomaly_value = 1000
df_final['YEARS_EMPLOYED'] = df_final['YEARS_EMPLOYED'].replace(anomaly_value, np.nan)
df_final['FLAG_EMP_ANOMALY'] = df_final['YEARS_EMPLOYED'].isnull().astype(int)
df_final['YEARS_EMPLOYED'] = df_final['YEARS_EMPLOYED'].fillna(0)

df_final
# Out:
# Number of people over 70 years old: 0
# Number of people working > 50 years: 38952
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  Pensioner  Secondary / secondary special
# 1       Commercial associate  Secondary / secondary special
# 2                    Working  Secondary / secondary special
# 3                  Pensioner  Secondary / secondary special
# 4                    Working  Secondary / secondary special
# ...                      ...                            ...
# 215252               Working  Secondary / secondary special
# 215253               Working  Secondary / secondary special
# 215254  Commercial associate              Incomplete higher
# 215255               Working  Secondary / secondary special
# 215256               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  AMT_ANNUITY  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0                      Widow      37800.0             0              1.0
# 1       Single / not married      40963.5             0              1.0
# 2                    Married      19795.5             1              3.0
# 3                    Married      60867.0             0              2.0
# 4                    Married      26316.0             0              2.0
# ...                      ...          ...           ...              ...
# 215252               Married      70956.0             0              2.0
# 215253               Married      14751.0             1              3.0
# 215254        Civil marriage      30258.0             0              2.0
# 215255             Separated      19206.0             0              1.0
# 215256               Married      28030.5             0              2.0
#
#         AMT_INCOME_TOTAL FLAG_OWN_CAR FLAG_OWN_REALTY  NAME_HOUSING_TYPE  \
# 0               427500.0            N               Y  House / apartment
# 1               180000.0            Y               Y  House / apartment
# 2               112500.0            Y               Y   Rented apartment
# 3               540000.0            N               Y  House / apartment
# 4                76500.0            Y               Y  House / apartment
# ...                  ...          ...             ...                ...
# 215252          144000.0            Y               N  House / apartment
# 215253          148500.0            N               N       With parents
# 215254          270000.0            Y               Y  House / apartment
# 215255          225000.0            N               Y  House / apartment
# 215256          189000.0            N               Y  House / apartment
#
#         AMT_CREDIT  TARGET  AGE_YEARS  YEARS_EMPLOYED  FLAG_EMP_ANOMALY
# 0        1288350.0       0         60             0.0                 1
# 1         848745.0       0         23             0.0                 0
# 2         385164.0       0         31             7.0                 0
# 3        1433520.0       0         58             0.0                 1
# 4         900000.0       0         58            37.0                 0
# ...            ...     ...        ...             ...               ...
# 215252    701730.0       0         50             4.0                 0
# 215253    254700.0       0         29             6.0                 0
# 215254   1030500.0       0         42             5.0                 0
# 215255    433057.5       1         53             4.0                 0
# 215256    954207.0       0         52             4.0                 0
#
# [215257 rows x 15 columns]

# %%
df_final['CREDIT_INCOME_RATIO'] = df_final['AMT_CREDIT'] / df_final['AMT_INCOME_TOTAL']
df_final['ADULT_IN_HOUSE'] = df_final['CNT_FAM_MEMBERS'] - df_final['CNT_CHILDREN']
df_final['EST_LOAN_TERM'] = (np.ceil(df_final['AMT_CREDIT'] / df_final['AMT_ANNUITY']) + 1).astype(int)
df_final = df_final.drop(columns = ["AMT_CREDIT"])
df_final
# Out:
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  Pensioner  Secondary / secondary special
# 1       Commercial associate  Secondary / secondary special
# 2                    Working  Secondary / secondary special
# 3                  Pensioner  Secondary / secondary special
# 4                    Working  Secondary / secondary special
# ...                      ...                            ...
# 215252               Working  Secondary / secondary special
# 215253               Working  Secondary / secondary special
# 215254  Commercial associate              Incomplete higher
# 215255               Working  Secondary / secondary special
# 215256               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  AMT_ANNUITY  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0                      Widow      37800.0             0              1.0
# 1       Single / not married      40963.5             0              1.0
# 2                    Married      19795.5             1              3.0
# 3                    Married      60867.0             0              2.0
# 4                    Married      26316.0             0              2.0
# ...                      ...          ...           ...              ...
# 215252               Married      70956.0             0              2.0
# 215253               Married      14751.0             1              3.0
# 215254        Civil marriage      30258.0             0              2.0
# 215255             Separated      19206.0             0              1.0
# 215256               Married      28030.5             0              2.0
#
#         AMT_INCOME_TOTAL FLAG_OWN_CAR FLAG_OWN_REALTY  NAME_HOUSING_TYPE  \
# 0               427500.0            N               Y  House / apartment
# 1               180000.0            Y               Y  House / apartment
# 2               112500.0            Y               Y   Rented apartment
# 3               540000.0            N               Y  House / apartment
# 4                76500.0            Y               Y  House / apartment
# ...                  ...          ...             ...                ...
# 215252          144000.0            Y               N  House / apartment
# 215253          148500.0            N               N       With parents
# 215254          270000.0            Y               Y  House / apartment
# 215255          225000.0            N               Y  House / apartment
# 215256          189000.0            N               Y  House / apartment
#
#         TARGET  AGE_YEARS  YEARS_EMPLOYED  FLAG_EMP_ANOMALY  \
# 0            0         60             0.0                 1
# 1            0         23             0.0                 0
# 2            0         31             7.0                 0
# 3            0         58             0.0                 1
# 4            0         58            37.0                 0
# ...        ...        ...             ...               ...
# 215252       0         50             4.0                 0
# 215253       0         29             6.0                 0
# 215254       0         42             5.0                 0
# 215255       1         53             4.0                 0
# 215256       0         52             4.0                 0
#
#         CREDIT_INCOME_RATIO  ADULT_IN_HOUSE  EST_LOAN_TERM
# 0                  3.013684             1.0             36
# 1                  4.715250             1.0             22
# 2                  3.423680             2.0             21
# 3                  2.654667             2.0             25
# 4                 11.764706             2.0             36
# ...                     ...             ...            ...
# 215252             4.873125             2.0             11
# 215253             1.715152             2.0             19
# 215254             3.816667             2.0             36
# 215255             1.924700             1.0             24
# 215256             5.048714             2.0             36
#
# [215257 rows x 17 columns]

# %%
df_final["ANNUITY_MONTHLY_INCOME_RATIO"] = df_final["AMT_ANNUITY"] / (df_final["AMT_INCOME_TOTAL"]/12)
df_final = df_final.drop(columns = ["AMT_INCOME_TOTAL", "AMT_ANNUITY"])
df_final
# Out:
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  Pensioner  Secondary / secondary special
# 1       Commercial associate  Secondary / secondary special
# 2                    Working  Secondary / secondary special
# 3                  Pensioner  Secondary / secondary special
# 4                    Working  Secondary / secondary special
# ...                      ...                            ...
# 215252               Working  Secondary / secondary special
# 215253               Working  Secondary / secondary special
# 215254  Commercial associate              Incomplete higher
# 215255               Working  Secondary / secondary special
# 215256               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  CNT_CHILDREN  CNT_FAM_MEMBERS FLAG_OWN_CAR  \
# 0                      Widow             0              1.0            N
# 1       Single / not married             0              1.0            Y
# 2                    Married             1              3.0            Y
# 3                    Married             0              2.0            N
# 4                    Married             0              2.0            Y
# ...                      ...           ...              ...          ...
# 215252               Married             0              2.0            Y
# 215253               Married             1              3.0            N
# 215254        Civil marriage             0              2.0            Y
# 215255             Separated             0              1.0            N
# 215256               Married             0              2.0            N
#
#        FLAG_OWN_REALTY  NAME_HOUSING_TYPE  TARGET  AGE_YEARS  YEARS_EMPLOYED  \
# 0                    Y  House / apartment       0         60             0.0
# 1                    Y  House / apartment       0         23             0.0
# 2                    Y   Rented apartment       0         31             7.0
# 3                    Y  House / apartment       0         58             0.0
# 4                    Y  House / apartment       0         58            37.0
# ...                ...                ...     ...        ...             ...
# 215252               N  House / apartment       0         50             4.0
# 215253               N       With parents       0         29             6.0
# 215254               Y  House / apartment       0         42             5.0
# 215255               Y  House / apartment       1         53             4.0
# 215256               Y  House / apartment       0         52             4.0
#
#         FLAG_EMP_ANOMALY  CREDIT_INCOME_RATIO  ADULT_IN_HOUSE  EST_LOAN_TERM  \
# 0                      1             3.013684             1.0             36
# 1                      0             4.715250             1.0             22
# 2                      0             3.423680             2.0             21
# 3                      1             2.654667             2.0             25
# 4                      0            11.764706             2.0             36
# ...                  ...                  ...             ...            ...
# 215252                 0             4.873125             2.0             11
# 215253                 0             1.715152             2.0             19
# 215254                 0             3.816667             2.0             36
# 215255                 0             1.924700             1.0             24
# 215256                 0             5.048714             2.0             36
#
#         ANNUITY_MONTHLY_INCOME_RATIO
# 0                           1.061053
# 1                           2.730900
# 2                           2.111520
# 3                           1.352600
# 4                           4.128000
# ...                              ...
# 215252                      5.913000
# 215253                      1.192000
# 215254                      1.344800
# 215255                      1.024320
# 215256                      1.779714
#
# [215257 rows x 16 columns]

# %%
corr_matrix = df_final[["ANNUITY_MONTHLY_INCOME_RATIO", "CREDIT_INCOME_RATIO", "ADULT_IN_HOUSE", "EST_LOAN_TERM"]]

corr_matrix.corr()
# Out:
#                               ANNUITY_MONTHLY_INCOME_RATIO  \
# ANNUITY_MONTHLY_INCOME_RATIO                      1.000000
# CREDIT_INCOME_RATIO                               0.788348
# ADULT_IN_HOUSE                                    0.122360
# EST_LOAN_TERM                                     0.069087
#
#                               CREDIT_INCOME_RATIO  ADULT_IN_HOUSE  \
# ANNUITY_MONTHLY_INCOME_RATIO             0.788348        0.122360
# CREDIT_INCOME_RATIO                      1.000000        0.127033
# ADULT_IN_HOUSE                           0.127033        1.000000
# EST_LOAN_TERM                            0.602708        0.058915
#
#                               EST_LOAN_TERM
# ANNUITY_MONTHLY_INCOME_RATIO       0.069087
# CREDIT_INCOME_RATIO                0.602708
# ADULT_IN_HOUSE                     0.058915
# EST_LOAN_TERM                      1.000000

# %%
df_final["CHILDREN_TO_FAMILY_RATIO"] = df_final["CNT_CHILDREN"] / df_final["CNT_FAM_MEMBERS"]

df_final = df_final.drop(columns = ["CNT_FAM_MEMBERS"])

# %%
df_final
# Out:
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  Pensioner  Secondary / secondary special
# 1       Commercial associate  Secondary / secondary special
# 2                    Working  Secondary / secondary special
# 3                  Pensioner  Secondary / secondary special
# 4                    Working  Secondary / secondary special
# ...                      ...                            ...
# 215252               Working  Secondary / secondary special
# 215253               Working  Secondary / secondary special
# 215254  Commercial associate              Incomplete higher
# 215255               Working  Secondary / secondary special
# 215256               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  CNT_CHILDREN FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0                      Widow             0            N               Y
# 1       Single / not married             0            Y               Y
# 2                    Married             1            Y               Y
# 3                    Married             0            N               Y
# 4                    Married             0            Y               Y
# ...                      ...           ...          ...             ...
# 215252               Married             0            Y               N
# 215253               Married             1            N               N
# 215254        Civil marriage             0            Y               Y
# 215255             Separated             0            N               Y
# 215256               Married             0            N               Y
#
#         NAME_HOUSING_TYPE  TARGET  AGE_YEARS  YEARS_EMPLOYED  \
# 0       House / apartment       0         60             0.0
# 1       House / apartment       0         23             0.0
# 2        Rented apartment       0         31             7.0
# 3       House / apartment       0         58             0.0
# 4       House / apartment       0         58            37.0
# ...                   ...     ...        ...             ...
# 215252  House / apartment       0         50             4.0
# 215253       With parents       0         29             6.0
# 215254  House / apartment       0         42             5.0
# 215255  House / apartment       1         53             4.0
# 215256  House / apartment       0         52             4.0
#
#         FLAG_EMP_ANOMALY  CREDIT_INCOME_RATIO  ADULT_IN_HOUSE  EST_LOAN_TERM  \
# 0                      1             3.013684             1.0             36
# 1                      0             4.715250             1.0             22
# 2                      0             3.423680             2.0             21
# 3                      1             2.654667             2.0             25
# 4                      0            11.764706             2.0             36
# ...                  ...                  ...             ...            ...
# 215252                 0             4.873125             2.0             11
# 215253                 0             1.715152             2.0             19
# 215254                 0             3.816667             2.0             36
# 215255                 0             1.924700             1.0             24
# 215256                 0             5.048714             2.0             36
#
#         ANNUITY_MONTHLY_INCOME_RATIO  CHILDREN_TO_FAMILY_RATIO
# 0                           1.061053                  0.000000
# 1                           2.730900                  0.000000
# 2                           2.111520                  0.333333
# 3                           1.352600                  0.000000
# 4                           4.128000                  0.000000
# ...                              ...                       ...
# 215252                      5.913000                  0.000000
# 215253                      1.192000                  0.333333
# 215254                      1.344800                  0.000000
# 215255                      1.024320                  0.000000
# 215256                      1.779714                  0.000000
#
# [215257 rows x 16 columns]

# %%
numerical_cols = [
    'AGE_YEARS', 'YEARS_EMPLOYED', 'CNT_CHILDREN', 'ANNUITY_MONTHLY_INCOME_RATIO', "EST_LOAN_TERM",
    'CREDIT_INCOME_RATIO', "ADULT_IN_HOUSE", "CHILDREN_TO_FAMILY_RATIO", 
]
    
# 1. Add your TARGET column to the list of numerical columns you want to plot
cols_for_pairplot = numerical_cols + ['TARGET']

# 2. Take your 5,000 row sample (CRITICAL: now including the TARGET column)
df_sample = df_final[cols_for_pairplot].sample(n=50000, random_state=40)

# 3. Draw the Pairplot with Color-Coding
sns.pairplot(
    df_sample, 
    hue='TARGET',                     # <--- THIS IS THE MAGIC PARAMETER
    diag_kind='kde', 
    corner=True, 
    palette={0: '#2ecc71', 1: '#e74c3c'},  # Green = Repaid (0), Red = Defaulted (1)
    plot_kws={'alpha': 0.4, 's': 15}       # alpha makes dots transparent, 's' makes them smaller
)

plt.suptitle("Pairplot by Loan Status (Default vs Repaid)", y=1.02, fontsize=14)
plt.show()

# %%
df_final["NAME_INCOME_TYPE"] = df_final["NAME_INCOME_TYPE"].replace("Businessman", "Commercial associate")

df_final
# Out:
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  Pensioner  Secondary / secondary special
# 1       Commercial associate  Secondary / secondary special
# 2                    Working  Secondary / secondary special
# 3                  Pensioner  Secondary / secondary special
# 4                    Working  Secondary / secondary special
# ...                      ...                            ...
# 215252               Working  Secondary / secondary special
# 215253               Working  Secondary / secondary special
# 215254  Commercial associate              Incomplete higher
# 215255               Working  Secondary / secondary special
# 215256               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  CNT_CHILDREN FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0                      Widow             0            N               Y
# 1       Single / not married             0            Y               Y
# 2                    Married             1            Y               Y
# 3                    Married             0            N               Y
# 4                    Married             0            Y               Y
# ...                      ...           ...          ...             ...
# 215252               Married             0            Y               N
# 215253               Married             1            N               N
# 215254        Civil marriage             0            Y               Y
# 215255             Separated             0            N               Y
# 215256               Married             0            N               Y
#
#         NAME_HOUSING_TYPE  TARGET  AGE_YEARS  YEARS_EMPLOYED  \
# 0       House / apartment       0         60             0.0
# 1       House / apartment       0         23             0.0
# 2        Rented apartment       0         31             7.0
# 3       House / apartment       0         58             0.0
# 4       House / apartment       0         58            37.0
# ...                   ...     ...        ...             ...
# 215252  House / apartment       0         50             4.0
# 215253       With parents       0         29             6.0
# 215254  House / apartment       0         42             5.0
# 215255  House / apartment       1         53             4.0
# 215256  House / apartment       0         52             4.0
#
#         FLAG_EMP_ANOMALY  CREDIT_INCOME_RATIO  ADULT_IN_HOUSE  EST_LOAN_TERM  \
# 0                      1             3.013684             1.0             36
# 1                      0             4.715250             1.0             22
# 2                      0             3.423680             2.0             21
# 3                      1             2.654667             2.0             25
# 4                      0            11.764706             2.0             36
# ...                  ...                  ...             ...            ...
# 215252                 0             4.873125             2.0             11
# 215253                 0             1.715152             2.0             19
# 215254                 0             3.816667             2.0             36
# 215255                 0             1.924700             1.0             24
# 215256                 0             5.048714             2.0             36
#
#         ANNUITY_MONTHLY_INCOME_RATIO  CHILDREN_TO_FAMILY_RATIO
# 0                           1.061053                  0.000000
# 1                           2.730900                  0.000000
# 2                           2.111520                  0.333333
# 3                           1.352600                  0.000000
# 4                           4.128000                  0.000000
# ...                              ...                       ...
# 215252                      5.913000                  0.000000
# 215253                      1.192000                  0.333333
# 215254                      1.344800                  0.000000
# 215255                      1.024320                  0.000000
# 215256                      1.779714                  0.000000
#
# [215257 rows x 16 columns]

# %%
df_final[df_final["NAME_INCOME_TYPE"] == "Businessman"]
# Out:
# Empty DataFrame
# Columns: [NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, CNT_CHILDREN, FLAG_OWN_CAR, FLAG_OWN_REALTY, NAME_HOUSING_TYPE, TARGET, AGE_YEARS, YEARS_EMPLOYED, FLAG_EMP_ANOMALY, CREDIT_INCOME_RATIO, ADULT_IN_HOUSE, EST_LOAN_TERM, ANNUITY_MONTHLY_INCOME_RATIO, CHILDREN_TO_FAMILY_RATIO]
# Index: []

# %%
# 1. Clean Income Type
income_to_replace = ['Unemployed', 'Student', 'Maternity leave']
df_final['NAME_INCOME_TYPE'] = df_final['NAME_INCOME_TYPE'].replace(income_to_replace, 'Other')

# 2. Clean Education Type
df_final['NAME_EDUCATION_TYPE'] = df_final['NAME_EDUCATION_TYPE'].replace(['Academic degree'], 'Higher education')

# 3. Clean Housing Type
housing_to_replace = ['Office apartment', 'Co-op apartment']
df_final['NAME_HOUSING_TYPE'] = df_final['NAME_HOUSING_TYPE'].replace(housing_to_replace, 'Other_Rented')
df_final['NAME_EDUCATION_TYPE'] = df_final['NAME_EDUCATION_TYPE'].replace('Secondary / secondary special', 'Secondary Education') 

# Verify the new, cleaner distributions
print(df_final['NAME_INCOME_TYPE'].value_counts())
print(df_final['NAME_HOUSING_TYPE'].value_counts())
print(df_final['NAME_EDUCATION_TYPE'].value_counts())
# Out:
# NAME_INCOME_TYPE
# Working                 111213
# Commercial associate     49957
# Pensioner                38940
# State servant            15113
# Other                       34
# Name: count, dtype: int64
# NAME_HOUSING_TYPE
# House / apartment      190886
# With parents            10445
# Municipal apartment      7859
# Rented apartment         3421
# Other_Rented             2646
# Name: count, dtype: int64
# NAME_EDUCATION_TYPE
# Secondary Education    152963
# Higher education        52392
# Incomplete higher        7214
# Lower secondary          2688
# Name: count, dtype: int64

# %%
df_final
# Out:
#             NAME_INCOME_TYPE  NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0                  Pensioner  Secondary Education                 Widow
# 1       Commercial associate  Secondary Education  Single / not married
# 2                    Working  Secondary Education               Married
# 3                  Pensioner  Secondary Education               Married
# 4                    Working  Secondary Education               Married
# ...                      ...                  ...                   ...
# 215252               Working  Secondary Education               Married
# 215253               Working  Secondary Education               Married
# 215254  Commercial associate    Incomplete higher        Civil marriage
# 215255               Working  Secondary Education             Separated
# 215256               Working  Secondary Education               Married
#
#         CNT_CHILDREN FLAG_OWN_CAR FLAG_OWN_REALTY  NAME_HOUSING_TYPE  TARGET  \
# 0                  0            N               Y  House / apartment       0
# 1                  0            Y               Y  House / apartment       0
# 2                  1            Y               Y   Rented apartment       0
# 3                  0            N               Y  House / apartment       0
# 4                  0            Y               Y  House / apartment       0
# ...              ...          ...             ...                ...     ...
# 215252             0            Y               N  House / apartment       0
# 215253             1            N               N       With parents       0
# 215254             0            Y               Y  House / apartment       0
# 215255             0            N               Y  House / apartment       1
# 215256             0            N               Y  House / apartment       0
#
#         AGE_YEARS  YEARS_EMPLOYED  FLAG_EMP_ANOMALY  CREDIT_INCOME_RATIO  \
# 0              60             0.0                 1             3.013684
# 1              23             0.0                 0             4.715250
# 2              31             7.0                 0             3.423680
# 3              58             0.0                 1             2.654667
# 4              58            37.0                 0            11.764706
# ...           ...             ...               ...                  ...
# 215252         50             4.0                 0             4.873125
# 215253         29             6.0                 0             1.715152
# 215254         42             5.0                 0             3.816667
# 215255         53             4.0                 0             1.924700
# 215256         52             4.0                 0             5.048714
#
#         ADULT_IN_HOUSE  EST_LOAN_TERM  ANNUITY_MONTHLY_INCOME_RATIO  \
# 0                  1.0             36                      1.061053
# 1                  1.0             22                      2.730900
# 2                  2.0             21                      2.111520
# 3                  2.0             25                      1.352600
# 4                  2.0             36                      4.128000
# ...                ...            ...                           ...
# 215252             2.0             11                      5.913000
# 215253             2.0             19                      1.192000
# 215254             2.0             36                      1.344800
# 215255             1.0             24                      1.024320
# 215256             2.0             36                      1.779714
#
#         CHILDREN_TO_FAMILY_RATIO
# 0                       0.000000
# 1                       0.000000
# 2                       0.333333
# 3                       0.000000
# 4                       0.000000
# ...                          ...
# 215252                  0.000000
# 215253                  0.333333
# 215254                  0.000000
# 215255                  0.000000
# 215256                  0.000000
#
# [215257 rows x 16 columns]

# %%
df_final.to_csv('data/cleaned_loan_data_revised_v4.csv', index=False)

print("Success! The cleaned data has been saved as 'cleaned_loan_data_revised_v4.csv'")
# Out:
# Success! The cleaned data has been saved as 'cleaned_loan_data_revised_v4.csv'
